# %% [markdown]
# # Результаты фильтрации временных рядов
#
# Фильтрация выполнена для 41 ионосферной станции на регулярной 15-минутной временной сетке. В обработку включено 2 381 519 временных строк и 19 052 152 значений по восьми параметрам: foF2, foF1, foE, MUF_D, hmF2, TEC, fmin и foF2p.
#
# Процедура включала фильтр Хампеля и каузальное скользящее медианное сглаживание. Показатель измененных точек относится ко всей процедуре фильтрации, а не только к числу выбросов, найденных фильтром Хампеля.

# %% [markdown]
# ## Изменения по параметрам
#
# Суммарно изменено 9 753 707 значений, что составляет 51,2% от общего числа обработанных значений.
#
# | Параметр | Измененных значений | Средняя доля изменений |
# |---|---:|---:|
# | foF2 | 1 738 017 | 72,7% |
# | MUF_D | 1 600 938 | 66,4% |
# | hmF2 | 1 555 643 | 65,6% |
# | foF2p | 1 401 069 | 60,8% |
# | fmin | 1 358 783 | 56,6% |
# | TEC | 1 102 065 | 49,7% |
# | foE | 693 382 | 29,9% |
# | foF1 | 303 810 | 12,6% |

# %% [markdown]
# ![Рисунок 1 - Средняя доля измененных значений после фильтрации по параметрам](../reports/filtering_analysis/filtering_changed_share_by_parameter.png)

# %% [markdown]
# ## Изменения по широтным зонам
#
# | Широтная зона | Станций | Временных строк | Измененных значений | Средняя доля изменений | Медианная доля изменений |
# |---|---:|---:|---:|---:|---:|
# | Низкие широты | 12 | 720 458 | 2 736 305 | 49,4% | 43,6% |
# | Северные высокие широты | 3 | 161 463 | 610 365 | 42,0% | 49,1% |
# | Северные средние широты | 21 | 1 196 442 | 5 442 989 | 57,4% | 59,4% |
# | Южные средние широты | 5 | 303 156 | 964 048 | 39,5% | 40,4% |

# %% [markdown]
# ![Рисунок 2 - Распределение доли измененных значений после фильтрации по широтным зонам](../reports/filtering_analysis/filtering_changed_share_distribution_by_zone.png)

# %% [markdown]
# ## Станции с наибольшей долей изменений
#
# | Станция | Временных строк | Широтная зона | Измененных значений | Доля изменений |
# |---|---:|---|---:|---:|
# | EB040 | 70 176 | Северные средние широты | 377 217 | 67,2% |
# | DB049 | 70 176 | Северные средние широты | 369 791 | 65,9% |
# | WP937 | 9 808 | Северные средние широты | 51 104 | 65,1% |
# | JR055 | 70 176 | Северные средние широты | 364 583 | 64,9% |
# | EA036 | 35 136 | Северные средние широты | 181 999 | 64,7% |
# | CGK21 | 2 165 | Низкие широты | 11 169 | 64,5% |
# | PQ052 | 70 051 | Северные средние широты | 360 492 | 64,3% |
# | AU930 | 12 569 | Северные средние широты | 64 149 | 63,8% |
# | WA619 | 35 136 | Низкие широты | 175 285 | 62,4% |
# | JJ433 | 70 176 | Северные средние широты | 347 445 | 61,9% |

# %% [markdown]
# ![Рисунок 3 - Станции с наибольшей долей измененных значений после фильтрации](../reports/filtering_analysis/filtering_top_stations_by_changed_share.png)

# %% [markdown]
# ## Примеры рядов foF2 до и после фильтрации
#
# На рисунке приведены фрагменты временных рядов foF2 для станций из разных широтных зон. После фильтрации амплитуды одиночных отклонений относительно соседних точек становятся меньше.

# %% [markdown]
# ![Рисунок 4 - Примеры временных рядов foF2 до и после фильтрации](../reports/filtering_analysis/filtering_fof2_before_after_examples.png)

# %% [markdown]
# ## Методическое условие
#
# При построении фильтрации использовались каузальные скользящие окна: значение в момент времени T рассчитывалось только по текущей и предыдущим точкам временного ряда. Будущие значения при расчете фильтрованного значения не использовались. Это условие необходимо для последующего сравнения прогнозных моделей на данных без фильтрации и после фильтрации.
